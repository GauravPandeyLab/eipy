# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import RobustScaler
from sklearn.svm import LinearSVC, SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier, XGBRFClassifier
import sys
from ei import EnsembleIntegration, MeanAggregation, MedianAggregation
from interpretation import *
from utils import *
from sklearn.linear_model import Perceptron
from sklearn.datasets import make_classification

X, y = make_classification(n_samples=1000, n_features=20, n_redundant=0,
n_clusters_per_class=1, weights=[0.7], flip_y=0, random_state=1)

X_view_0 = X[:, :5]
X_view_1 = X[:, 5:10]
X_view_2 = X[:, 10:15]
X_view_3 = X[:, 15:]

base_predictors = {
    'AdaBoost': AdaBoostClassifier(),
    "XGB": XGBClassifier(use_label_encoder=False),
    # "DT": DecisionTreeClassifier(),
    "Perceptron": Perceptron(),
    "RF": RandomForestClassifier(), 
    'GradientBoosting': GradientBoostingClassifier(),
    'KNN': KNeighborsClassifier(),
    'LR': LogisticRegression(),
    'NB': GaussianNB(),
    'MLP': MLPClassifier(),
    "SVM": SVC(kernel='linear', probability=True, max_iter=1e4),
}
meta_models = {
    'AdaBoost': AdaBoostClassifier(),
    "XGB": XGBClassifier(use_label_encoder=False),
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(),
    'GradientBoosting': GradientBoostingClassifier(),
    'KNN': KNeighborsClassifier(),
    'LR': LogisticRegression(),
    'NB': GaussianNB(),
    'MLP': MLPClassifier(),
    "SVM": SVC(kernel='linear', probability=True, max_iter=1e4),
    # "Voting": VotingClassifier()
    # "Mean": MeanAggregation(),
    # "Median": MedianAggregation()
}

EI = EnsembleIntegration(base_predictors=base_predictors,
                         k_outer=5,
                         k_inner=5,
                         n_samples=5,
                         sampling_strategy="undersampling",
                         sampling_aggregation="mean",
                         n_jobs=-1,  # set as -1 to use all available CPUs
                         random_state=42,
                         project_name="demo",
                        #  calibration=True
                        verbose=0
                         )

EI.save()
EI = EnsembleIntegration().load("EI.demo")

modalities = {"view_0": X_view_0,
              "view_1": X_view_1,
              "view_2": X_view_2,
              "view_3": X_view_3,}

# for name, modality in modalities.items():
#     EI.train_base(modality, y, base_predictors, modality=name)

# EI.save() # save EI as EI.demo
# Out:
# Saved to EI.demo

# %%
from sklearn.metrics import average_precision_score

EI_int = EI_interpreter(EI_object=EI,
                        base_predictors=base_predictors,
                        meta_models=meta_models,
                        modalities=modalities,
                        y=y,
                        metric=f_minority_score)
# print(EI_int.base_predictors)
# print(EI.base_predictors)
EI_int.rank_product_score()
# Out:
#  Working on view_0 data...
#
# Training base predictors on outer training sets...
#
#  Working on view_1 data...
#
# Training base predictors on outer training sets...
#
#  Working on view_2 data...
#
# Training base predictors on outer training sets...
#
#  Working on view_3 data...
#
# Training base predictors on outer training sets...
#      local_model_PI base predictor modality ensemble_method    LMR  \
# 0          0.017931       AdaBoost   view_0      S.AdaBoost  0.175
# 1          0.017931       AdaBoost   view_0      S.AdaBoost  0.175
# 2          0.017931       AdaBoost   view_0      S.AdaBoost  0.175
# 3          0.017931       AdaBoost   view_0      S.AdaBoost  0.175
# 4          0.017931       AdaBoost   view_0      S.AdaBoost  0.175
# ..              ...            ...      ...             ...    ...
# 995        0.006139            SVM   view_3      S.AdaBoost  0.550
# 996        0.006139            SVM   view_3      S.AdaBoost  0.550
# 997        0.006139            SVM   view_3      S.AdaBoost  0.550
# 998        0.006139            SVM   view_3      S.AdaBoost  0.550
# 999        0.006139            SVM   view_3      S.AdaBoost  0.550
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0            0.035
# 1         0.018505        view_0_1  0.6       0            0.105
# 2         0.015626        view_0_2  1.0       0            0.175
# 3         0.016212        view_0_3  0.8       0            0.140
# 4         0.018727        view_0_4  0.4       0            0.070
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4            0.440
# 996      -0.000227        view_3_1  0.4       4            0.220
# 997      -0.000071        view_3_2  0.2       4            0.110
# 998      -0.001681        view_3_3  1.0       4            0.550
# 999      -0.000465        view_3_4  0.6       4            0.330
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method    LMR  \
# 0               0.0       AdaBoost   view_0           S.XGB  0.575
# 1               0.0       AdaBoost   view_0           S.XGB  0.575
# 2               0.0       AdaBoost   view_0           S.XGB  0.575
# 3               0.0       AdaBoost   view_0           S.XGB  0.575
# 4               0.0       AdaBoost   view_0           S.XGB  0.575
# ..              ...            ...      ...             ...    ...
# 995             0.0            SVM   view_3           S.XGB  0.575
# 996             0.0            SVM   view_3           S.XGB  0.575
# 997             0.0            SVM   view_3           S.XGB  0.575
# 998             0.0            SVM   view_3           S.XGB  0.575
# 999             0.0            SVM   view_3           S.XGB  0.575
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0            0.115
# 1         0.018505        view_0_1  0.6       0            0.345
# 2         0.015626        view_0_2  1.0       0            0.575
# 3         0.016212        view_0_3  0.8       0            0.460
# 4         0.018727        view_0_4  0.4       0            0.230
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4            0.460
# 996      -0.000227        view_3_1  0.4       4            0.230
# 997      -0.000071        view_3_2  0.2       4            0.115
# 998      -0.001681        view_3_3  1.0       4            0.575
# 999      -0.000465        view_3_4  0.6       4            0.345
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method  LMR  \
# 0          0.025444       AdaBoost   view_0            S.DT  0.2
# 1          0.025444       AdaBoost   view_0            S.DT  0.2
# 2          0.025444       AdaBoost   view_0            S.DT  0.2
# 3          0.025444       AdaBoost   view_0            S.DT  0.2
# 4          0.025444       AdaBoost   view_0            S.DT  0.2
# ..              ...            ...      ...             ...  ...
# 995        0.007479            SVM   view_3            S.DT  0.4
# 996        0.007479            SVM   view_3            S.DT  0.4
# 997        0.007479            SVM   view_3            S.DT  0.4
# 998        0.007479            SVM   view_3            S.DT  0.4
# 999        0.007479            SVM   view_3            S.DT  0.4
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0             0.04
# 1         0.018505        view_0_1  0.6       0             0.12
# 2         0.015626        view_0_2  1.0       0             0.20
# 3         0.016212        view_0_3  0.8       0             0.16
# 4         0.018727        view_0_4  0.4       0             0.08
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4             0.32
# 996      -0.000227        view_3_1  0.4       4             0.16
# 997      -0.000071        view_3_2  0.2       4             0.08
# 998      -0.001681        view_3_3  1.0       4             0.40
# 999      -0.000465        view_3_4  0.6       4             0.24
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method     LMR  \
# 0          0.001664       AdaBoost   view_0            S.RF  0.0875
# 1          0.001664       AdaBoost   view_0            S.RF  0.0875
# 2          0.001664       AdaBoost   view_0            S.RF  0.0875
# 3          0.001664       AdaBoost   view_0            S.RF  0.0875
# 4          0.001664       AdaBoost   view_0            S.RF  0.0875
# ..              ...            ...      ...             ...     ...
# 995        0.000000            SVM   view_3            S.RF  0.6250
# 996        0.000000            SVM   view_3            S.RF  0.6250
# 997        0.000000            SVM   view_3            S.RF  0.6250
# 998        0.000000            SVM   view_3            S.RF  0.6250
# 999        0.000000            SVM   view_3            S.RF  0.6250
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0           0.0175
# 1         0.018505        view_0_1  0.6       0           0.0525
# 2         0.015626        view_0_2  1.0       0           0.0875
# 3         0.016212        view_0_3  0.8       0           0.0700
# 4         0.018727        view_0_4  0.4       0           0.0350
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4           0.5000
# 996      -0.000227        view_3_1  0.4       4           0.2500
# 997      -0.000071        view_3_2  0.2       4           0.1250
# 998      -0.001681        view_3_3  1.0       4           0.6250
# 999      -0.000465        view_3_4  0.6       4           0.3750
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality     ensemble_method  LMR  \
# 0           0.01090       AdaBoost   view_0  S.GradientBoosting  0.2
# 1           0.01090       AdaBoost   view_0  S.GradientBoosting  0.2
# 2           0.01090       AdaBoost   view_0  S.GradientBoosting  0.2
# 3           0.01090       AdaBoost   view_0  S.GradientBoosting  0.2
# 4           0.01090       AdaBoost   view_0  S.GradientBoosting  0.2
# ..              ...            ...      ...                 ...  ...
# 995         0.00231            SVM   view_3  S.GradientBoosting  0.6
# 996         0.00231            SVM   view_3  S.GradientBoosting  0.6
# 997         0.00231            SVM   view_3  S.GradientBoosting  0.6
# 998         0.00231            SVM   view_3  S.GradientBoosting  0.6
# 999         0.00231            SVM   view_3  S.GradientBoosting  0.6
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0             0.04
# 1         0.018505        view_0_1  0.6       0             0.12
# 2         0.015626        view_0_2  1.0       0             0.20
# 3         0.016212        view_0_3  0.8       0             0.16
# 4         0.018727        view_0_4  0.4       0             0.08
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4             0.48
# 996      -0.000227        view_3_1  0.4       4             0.24
# 997      -0.000071        view_3_2  0.2       4             0.12
# 998      -0.001681        view_3_3  1.0       4             0.60
# 999      -0.000465        view_3_4  0.6       4             0.36
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method     LMR  \
# 0               0.0       AdaBoost   view_0           S.KNN  0.5875
# 1               0.0       AdaBoost   view_0           S.KNN  0.5875
# 2               0.0       AdaBoost   view_0           S.KNN  0.5875
# 3               0.0       AdaBoost   view_0           S.KNN  0.5875
# 4               0.0       AdaBoost   view_0           S.KNN  0.5875
# ..              ...            ...      ...             ...     ...
# 995             0.0            SVM   view_3           S.KNN  0.5875
# 996             0.0            SVM   view_3           S.KNN  0.5875
# 997             0.0            SVM   view_3           S.KNN  0.5875
# 998             0.0            SVM   view_3           S.KNN  0.5875
# 999             0.0            SVM   view_3           S.KNN  0.5875
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0           0.1175
# 1         0.018505        view_0_1  0.6       0           0.3525
# 2         0.015626        view_0_2  1.0       0           0.5875
# 3         0.016212        view_0_3  0.8       0           0.4700
# 4         0.018727        view_0_4  0.4       0           0.2350
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4           0.4700
# 996      -0.000227        view_3_1  0.4       4           0.2350
# 997      -0.000071        view_3_2  0.2       4           0.1175
# 998      -0.001681        view_3_3  1.0       4           0.5875
# 999      -0.000465        view_3_4  0.6       4           0.3525
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method     LMR  \
# 0          0.000599       AdaBoost   view_0            S.LR  0.2250
# 1          0.000599       AdaBoost   view_0            S.LR  0.2250
# 2          0.000599       AdaBoost   view_0            S.LR  0.2250
# 3          0.000599       AdaBoost   view_0            S.LR  0.2250
# 4          0.000599       AdaBoost   view_0            S.LR  0.2250
# ..              ...            ...      ...             ...     ...
# 995        0.000000            SVM   view_3            S.LR  0.5875
# 996        0.000000            SVM   view_3            S.LR  0.5875
# 997        0.000000            SVM   view_3            S.LR  0.5875
# 998        0.000000            SVM   view_3            S.LR  0.5875
# 999        0.000000            SVM   view_3            S.LR  0.5875
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0           0.0450
# 1         0.018505        view_0_1  0.6       0           0.1350
# 2         0.015626        view_0_2  1.0       0           0.2250
# 3         0.016212        view_0_3  0.8       0           0.1800
# 4         0.018727        view_0_4  0.4       0           0.0900
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4           0.4700
# 996      -0.000227        view_3_1  0.4       4           0.2350
# 997      -0.000071        view_3_2  0.2       4           0.1175
# 998      -0.001681        view_3_3  1.0       4           0.5875
# 999      -0.000465        view_3_4  0.6       4           0.3525
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method     LMR  \
# 0          0.000000       AdaBoost   view_0            S.NB  0.6375
# 1          0.000000       AdaBoost   view_0            S.NB  0.6375
# 2          0.000000       AdaBoost   view_0            S.NB  0.6375
# 3          0.000000       AdaBoost   view_0            S.NB  0.6375
# 4          0.000000       AdaBoost   view_0            S.NB  0.6375
# ..              ...            ...      ...             ...     ...
# 995        0.000622            SVM   view_3            S.NB  0.1500
# 996        0.000622            SVM   view_3            S.NB  0.1500
# 997        0.000622            SVM   view_3            S.NB  0.1500
# 998        0.000622            SVM   view_3            S.NB  0.1500
# 999        0.000622            SVM   view_3            S.NB  0.1500
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0           0.1275
# 1         0.018505        view_0_1  0.6       0           0.3825
# 2         0.015626        view_0_2  1.0       0           0.6375
# 3         0.016212        view_0_3  0.8       0           0.5100
# 4         0.018727        view_0_4  0.4       0           0.2550
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4           0.1200
# 996      -0.000227        view_3_1  0.4       4           0.0600
# 997      -0.000071        view_3_2  0.2       4           0.0300
# 998      -0.001681        view_3_3  1.0       4           0.1500
# 999      -0.000465        view_3_4  0.6       4           0.0900
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method    LMR  \
# 0          0.001932       AdaBoost   view_0           S.MLP  0.375
# 1          0.001932       AdaBoost   view_0           S.MLP  0.375
# 2          0.001932       AdaBoost   view_0           S.MLP  0.375
# 3          0.001932       AdaBoost   view_0           S.MLP  0.375
# 4          0.001932       AdaBoost   view_0           S.MLP  0.375
# ..              ...            ...      ...             ...    ...
# 995        0.000152            SVM   view_3           S.MLP  0.825
# 996        0.000152            SVM   view_3           S.MLP  0.825
# 997        0.000152            SVM   view_3           S.MLP  0.825
# 998        0.000152            SVM   view_3           S.MLP  0.825
# 999        0.000152            SVM   view_3           S.MLP  0.825
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0            0.075
# 1         0.018505        view_0_1  0.6       0            0.225
# 2         0.015626        view_0_2  1.0       0            0.375
# 3         0.016212        view_0_3  0.8       0            0.300
# 4         0.018727        view_0_4  0.4       0            0.150
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4            0.660
# 996      -0.000227        view_3_1  0.4       4            0.330
# 997      -0.000071        view_3_2  0.2       4            0.165
# 998      -0.001681        view_3_3  1.0       4            0.825
# 999      -0.000465        view_3_4  0.6       4            0.495
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method     LMR  \
# 0          0.000113       AdaBoost   view_0           S.SVM  0.4250
# 1          0.000113       AdaBoost   view_0           S.SVM  0.4250
# 2          0.000113       AdaBoost   view_0           S.SVM  0.4250
# 3          0.000113       AdaBoost   view_0           S.SVM  0.4250
# 4          0.000113       AdaBoost   view_0           S.SVM  0.4250
# ..              ...            ...      ...             ...     ...
# 995        0.000000            SVM   view_3           S.SVM  0.6125
# 996        0.000000            SVM   view_3           S.SVM  0.6125
# 997        0.000000            SVM   view_3           S.SVM  0.6125
# 998        0.000000            SVM   view_3           S.SVM  0.6125
# 999        0.000000            SVM   view_3           S.SVM  0.6125
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0           0.0850
# 1         0.018505        view_0_1  0.6       0           0.2550
# 2         0.015626        view_0_2  1.0       0           0.4250
# 3         0.016212        view_0_3  0.8       0           0.3400
# 4         0.018727        view_0_4  0.4       0           0.1700
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4           0.4900
# 996      -0.000227        view_3_1  0.4       4           0.2450
# 997      -0.000071        view_3_2  0.2       4           0.1225
# 998      -0.001681        view_3_3  1.0       4           0.6125
# 999      -0.000465        view_3_4  0.6       4           0.3675
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method     LMR  \
# 0               1.0       AdaBoost   view_0            Mean  0.5125
# 1               1.0       AdaBoost   view_0            Mean  0.5125
# 2               1.0       AdaBoost   view_0            Mean  0.5125
# 3               1.0       AdaBoost   view_0            Mean  0.5125
# 4               1.0       AdaBoost   view_0            Mean  0.5125
# ..              ...            ...      ...             ...     ...
# 995             1.0            SVM   view_3            Mean  0.5125
# 996             1.0            SVM   view_3            Mean  0.5125
# 997             1.0            SVM   view_3            Mean  0.5125
# 998             1.0            SVM   view_3            Mean  0.5125
# 999             1.0            SVM   view_3            Mean  0.5125
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0           0.1025
# 1         0.018505        view_0_1  0.6       0           0.3075
# 2         0.015626        view_0_2  1.0       0           0.5125
# 3         0.016212        view_0_3  0.8       0           0.4100
# 4         0.018727        view_0_4  0.4       0           0.2050
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4           0.4100
# 996      -0.000227        view_3_1  0.4       4           0.2050
# 997      -0.000071        view_3_2  0.2       4           0.1025
# 998      -0.001681        view_3_3  1.0       4           0.5125
# 999      -0.000465        view_3_4  0.6       4           0.3075
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method     LMR  \
# 0               1.0       AdaBoost   view_0          Median  0.5125
# 1               1.0       AdaBoost   view_0          Median  0.5125
# 2               1.0       AdaBoost   view_0          Median  0.5125
# 3               1.0       AdaBoost   view_0          Median  0.5125
# 4               1.0       AdaBoost   view_0          Median  0.5125
# ..              ...            ...      ...             ...     ...
# 995             1.0            SVM   view_3          Median  0.5125
# 996             1.0            SVM   view_3          Median  0.5125
# 997             1.0            SVM   view_3          Median  0.5125
# 998             1.0            SVM   view_3          Median  0.5125
# 999             1.0            SVM   view_3          Median  0.5125
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0           0.1025
# 1         0.018505        view_0_1  0.6       0           0.3075
# 2         0.015626        view_0_2  1.0       0           0.5125
# 3         0.016212        view_0_3  0.8       0           0.4100
# 4         0.018727        view_0_4  0.4       0           0.2050
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4           0.4100
# 996      -0.000227        view_3_1  0.4       4           0.2050
# 997      -0.000071        view_3_2  0.2       4           0.1025
# 998      -0.001681        view_3_3  1.0       4           0.5125
# 999      -0.000465        view_3_4  0.6       4           0.3075
#
# [1000 rows x 10 columns]
#      local_model_PI base predictor modality ensemble_method    LMR  \
# 0               1.0       AdaBoost   view_0             CES  0.325
# 1               1.0       AdaBoost   view_0             CES  0.325
# 2               1.0       AdaBoost   view_0             CES  0.325
# 3               1.0       AdaBoost   view_0             CES  0.325
# 4               1.0       AdaBoost   view_0             CES  0.325
# ..              ...            ...      ...             ...    ...
# 995             7.0            SVM   view_3             CES  0.025
# 996             7.0            SVM   view_3             CES  0.025
# 997             7.0            SVM   view_3             CES  0.025
# 998             7.0            SVM   view_3             CES  0.025
# 999             7.0            SVM   view_3             CES  0.025
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.022126        view_0_0  0.2       0            0.065
# 1         0.018505        view_0_1  0.6       0            0.195
# 2         0.015626        view_0_2  1.0       0            0.325
# 3         0.016212        view_0_3  0.8       0            0.260
# 4         0.018727        view_0_4  0.4       0            0.130
# ..             ...             ...  ...     ...              ...
# 995      -0.000523        view_3_0  0.8       4            0.020
# 996      -0.000227        view_3_1  0.4       4            0.010
# 997      -0.000071        view_3_2  0.2       4            0.005
# 998      -0.001681        view_3_3  1.0       4            0.025
# 999      -0.000465        view_3_4  0.6       4            0.015
#
# [1000 rows x 10 columns]
# Finished feature ranking of ensemble model(s)!

# %%
EI_int.ensemble_feature_ranking['S.XGB']
# Out:
#    modality   feature     RPS  feature rank ensemble method
# 11   view_2  view_2_1  0.0855           1.0           S.XGB
# 1    view_0  view_0_1  0.1788           2.0           S.XGB
# 9    view_1  view_1_4  0.2116           3.0           S.XGB
# 6    view_1  view_1_1  0.2668           4.0           S.XGB
# 4    view_0  view_0_4  0.2735           5.0           S.XGB
# 12   view_2  view_2_2  0.2747           6.0           S.XGB
# 2    view_0  view_0_2  0.2899           7.0           S.XGB
# 10   view_2  view_2_0  0.2950           8.0           S.XGB
# 19   view_3  view_3_4  0.3059           9.0           S.XGB
# 15   view_3  view_3_0  0.3082          10.0           S.XGB
# 14   view_2  view_2_4  0.3115          11.0           S.XGB
# 13   view_2  view_2_3  0.3158          12.0           S.XGB
# 16   view_3  view_3_1  0.3197          13.0           S.XGB
# 3    view_0  view_0_3  0.3306          14.0           S.XGB
# 7    view_1  view_1_2  0.3358          15.0           S.XGB
# 0    view_0  view_0_0  0.3447          16.0           S.XGB
# 17   view_3  view_3_2  0.3933          17.0           S.XGB
# 18   view_3  view_3_3  0.3979          18.0           S.XGB
# 8    view_1  view_1_3  0.4163          19.0           S.XGB
# 5    view_1  view_1_0  0.4945          20.0           S.XGB

# %%
EI_int.LFRs.loc[EI_int.LFRs['base predictor']=='Perceptron']
# Out:
#     local_feat_PI local_feat_name base predictor modality  LFR  sample
# 0             0.0        view_0_0     Perceptron   view_0  0.6       0
# 1             0.0        view_0_1     Perceptron   view_0  0.6       0
# 2             0.0        view_0_2     Perceptron   view_0  0.6       0
# 3             0.0        view_0_3     Perceptron   view_0  0.6       0
# 4             0.0        view_0_4     Perceptron   view_0  0.6       0
# ..            ...             ...            ...      ...  ...     ...
# 0             0.0        view_3_0     Perceptron   view_3  0.6       4
# 1             0.0        view_3_1     Perceptron   view_3  0.6       4
# 2             0.0        view_3_2     Perceptron   view_3  0.6       4
# 3             0.0        view_3_3     Perceptron   view_3  0.6       4
# 4             0.0        view_3_4     Perceptron   view_3  0.6       4
#
# [100 rows x 6 columns]

# %%
EI_int.LMRs
# Out:
#     local_model_PI    base predictor modality ensemble_method     LMR
# 0         0.002491          AdaBoost   view_0      S.AdaBoost  0.4000
# 1         0.001478                DT   view_0      S.AdaBoost  0.7250
# 2         0.007497  GradientBoosting   view_0      S.AdaBoost  0.2000
# 3         0.002099               KNN   view_0      S.AdaBoost  0.4750
# 4         0.002538                LR   view_0      S.AdaBoost  0.3750
# ..             ...               ...      ...             ...     ...
# 35        1.000000               MLP   view_3             CES  0.3625
# 36        1.000000                NB   view_3             CES  0.3625
# 37        0.000000                RF   view_3             CES  0.7500
# 38        7.000000               SVM   view_3             CES  0.0250
# 39        1.000000               XGB   view_3             CES  0.3625
#
# [520 rows x 5 columns]

# %%
EI_int.merged_lmr_lfr['S.XGB']
# Out:
#      local_model_PI base predictor modality ensemble_method    LMR  \
# 0     -3.330669e-17       AdaBoost   view_0           S.XGB  0.625
# 1     -3.330669e-17       AdaBoost   view_0           S.XGB  0.625
# 2     -3.330669e-17       AdaBoost   view_0           S.XGB  0.625
# 3     -3.330669e-17       AdaBoost   view_0           S.XGB  0.625
# 4     -3.330669e-17       AdaBoost   view_0           S.XGB  0.625
# ..              ...            ...      ...             ...    ...
# 995   -1.110223e-17            SVM   view_3           S.XGB  0.325
# 996   -1.110223e-17            SVM   view_3           S.XGB  0.325
# 997   -1.110223e-17            SVM   view_3           S.XGB  0.325
# 998   -1.110223e-17            SVM   view_3           S.XGB  0.325
# 999   -1.110223e-17            SVM   view_3           S.XGB  0.325
#
#      local_feat_PI local_feat_name  LFR  sample  LMR_LFR_product
# 0         0.035168        view_0_0  1.0       0            0.625
# 1         0.036390        view_0_1  0.8       0            0.500
# 2         0.062275        view_0_2  0.4       0            0.250
# 3         0.065453        view_0_3  0.2       0            0.125
# 4         0.049280        view_0_4  0.6       0            0.375
# ..             ...             ...  ...     ...              ...
# 995      -0.025192        view_3_0  1.0       4            0.325
# 996      -0.001903        view_3_1  0.4       4            0.130
# 997      -0.005680        view_3_2  0.6       4            0.195
# 998      -0.006238        view_3_3  0.8       4            0.260
# 999      -0.000419        view_3_4  0.2       4            0.065
#
# [1000 rows x 10 columns]
