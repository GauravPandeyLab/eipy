# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import RobustScaler
from sklearn.svm import LinearSVC, SVC
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier, XGBRFClassifier
import sys
from ei import EnsembleIntegration, MeanAggregation, MedianAggregation
from interpretation import *
from utils import *

from sklearn.datasets import make_classification

X, y = make_classification(n_samples=1000, n_features=20, n_redundant=0,
n_clusters_per_class=1, weights=[0.7], flip_y=0, random_state=1)

X_view_0 = X[:, :5]
X_view_1 = X[:, 5:10]
X_view_2 = X[:, 10:15]
X_view_3 = X[:, 15:]

base_predictors = {
    'AdaBoost': AdaBoostClassifier(),
    "XGB": XGBClassifier(use_label_encoder=False),
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(), 
    'GradientBoosting': GradientBoostingClassifier(),
    'KNN': KNeighborsClassifier(),
    'LR': LogisticRegression(),
    'NB': GaussianNB(),
    'MLP': MLPClassifier(),
    "SVM": SVC(kernel='linear', probability=True, max_iter=1e4),
}
meta_models = {
    'AdaBoost': AdaBoostClassifier(),
    "XGB": XGBClassifier(use_label_encoder=False),
    "DT": DecisionTreeClassifier(),
    "RF": RandomForestClassifier(),
    'GradientBoosting': GradientBoostingClassifier(),
    'KNN': KNeighborsClassifier(),
    'LR': LogisticRegression(),
    'NB': GaussianNB(),
    'MLP': MLPClassifier(),
    "SVM": SVC(kernel='linear', probability=True, max_iter=1e4),

    # "Mean": MeanAggregation(),
    # "Median": MedianAggregation()
}

EI = EnsembleIntegration(base_predictors=base_predictors,
                         k_outer=5,
                         k_inner=5,
                         n_samples=1,
                         sampling_strategy="undersampling",
                         sampling_aggregation="mean",
                         n_jobs=-1,  # set as -1 to use all available CPUs
                         random_state=42,
                         project_name="demo",
                         calibration=True)

modalities = {"view_0": X_view_0,
              "view_1": X_view_1,
              "view_2": X_view_2,
              "view_3": X_view_3,}

# for name, modality in modalities.items():
#     EI.train_base(modality, y, base_predictors, modality=name)

# EI.save() # save EI as EI.demo

# %%
from sklearn.metrics import average_precision_score

EI_int = EI_interpreter(EI_object=EI,
                        base_predictors=base_predictors,
                        meta_models=meta_models,
                        modalities=modalities,
                        y=y,
                        metric=auprc_sklearn)
print(EI_int.base_predictors)
print(EI.base_predictors)
EI_int.rank_product_score()
# Out:
# {'AdaBoost': AdaBoostClassifier(), 'XGB': XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), 'DT': DecisionTreeClassifier(), 'RF': RandomForestClassifier(), 'GradientBoosting': GradientBoostingClassifier(), 'KNN': KNeighborsClassifier(), 'LR': LogisticRegression(), 'NB': GaussianNB(), 'MLP': MLPClassifier(), 'SVM': SVC(kernel='linear', max_iter=10000.0, probability=True)}
# {'AdaBoost': AdaBoostClassifier(), 'XGB': XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, gamma=None,
#               gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None,
#               reg_alpha=None, reg_lambda=None, ...), 'DT': DecisionTreeClassifier(), 'RF': RandomForestClassifier(), 'GradientBoosting': GradientBoostingClassifier(), 'KNN': KNeighborsClassifier(), 'LR': LogisticRegression(), 'NB': GaussianNB(), 'MLP': MLPClassifier(), 'SVM': SVC(kernel='linear', max_iter=10000.0, probability=True)}
#
#  Working on view_0 data...
#
#
# view_0 modality: training base predictors on outer training sets...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done  41 out of  50 | elapsed:    6.6s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  47 out of  50 | elapsed:    8.7s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    8.8s finished
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#  Working on view_1 data...
#
#
# view_1 modality: training base predictors on outer training sets...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done  41 out of  50 | elapsed:    3.0s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done  47 out of  50 | elapsed:    3.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.0s finished
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#  Working on view_2 data...
#
#
# view_2 modality: training base predictors on outer training sets...
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done  41 out of  50 | elapsed:    4.6s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  47 out of  50 | elapsed:    6.0s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    6.3s finished
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
#  Working on view_3 data...
#
#
# view_3 modality: training base predictors on outer training sets...
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done  41 out of  50 | elapsed:    2.9s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  47 out of  50 | elapsed:    3.9s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.0s finished
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# None
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:702: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#     local_model_PI    base predictor modality  sample ensemble_method     LMR
# 0     0.000000e+00          AdaBoost   view_0       0      S.AdaBoost  0.5500
# 1     0.000000e+00               XGB   view_0       0      S.AdaBoost  0.5500
# 2     0.000000e+00                DT   view_0       0      S.AdaBoost  0.5500
# 3     0.000000e+00                RF   view_0       0      S.AdaBoost  0.5500
# 4     0.000000e+00  GradientBoosting   view_0       0      S.AdaBoost  0.5500
# ..             ...               ...      ...     ...             ...     ...
# 35   -1.174706e-04               KNN   view_3       0           S.SVM  0.8000
# 36   -6.610577e-05                LR   view_3       0           S.SVM  0.6375
# 37   -1.597330e-04                NB   view_3       0           S.SVM  0.9000
# 38    8.649144e-07               MLP   view_3       0           S.SVM  0.3750
# 39   -4.407051e-05               SVM   view_3       0           S.SVM  0.5500
#
# [400 rows x 6 columns]
#      local_model_PI base predictor modality  sample ensemble_method   LMR  \
# 0               0.0       AdaBoost   view_0       0      S.AdaBoost  0.55
# 1               0.0       AdaBoost   view_0       0      S.AdaBoost  0.55
# 2               0.0       AdaBoost   view_0       0      S.AdaBoost  0.55
# 3               0.0       AdaBoost   view_0       0      S.AdaBoost  0.55
# 4               0.0       AdaBoost   view_0       0      S.AdaBoost  0.55
# ..              ...            ...      ...     ...             ...   ...
# 195             0.0            SVM   view_3       0      S.AdaBoost  0.55
# 196             0.0            SVM   view_3       0      S.AdaBoost  0.55
# 197             0.0            SVM   view_3       0      S.AdaBoost  0.55
# 198             0.0            SVM   view_3       0      S.AdaBoost  0.55
# 199             0.0            SVM   view_3       0      S.AdaBoost  0.55
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample ensemble_method   LMR  \
# 0               0.0       AdaBoost   view_0       0           S.XGB  0.55
# 1               0.0       AdaBoost   view_0       0           S.XGB  0.55
# 2               0.0       AdaBoost   view_0       0           S.XGB  0.55
# 3               0.0       AdaBoost   view_0       0           S.XGB  0.55
# 4               0.0       AdaBoost   view_0       0           S.XGB  0.55
# ..              ...            ...      ...     ...             ...   ...
# 195             0.0            SVM   view_3       0           S.XGB  0.55
# 196             0.0            SVM   view_3       0           S.XGB  0.55
# 197             0.0            SVM   view_3       0           S.XGB  0.55
# 198             0.0            SVM   view_3       0           S.XGB  0.55
# 199             0.0            SVM   view_3       0           S.XGB  0.55
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample ensemble_method     LMR  \
# 0          0.000000       AdaBoost   view_0       0            S.DT  0.6375
# 1          0.000000       AdaBoost   view_0       0            S.DT  0.6375
# 2          0.000000       AdaBoost   view_0       0            S.DT  0.6375
# 3          0.000000       AdaBoost   view_0       0            S.DT  0.6375
# 4          0.000000       AdaBoost   view_0       0            S.DT  0.6375
# ..              ...            ...      ...     ...             ...     ...
# 195        0.068631            SVM   view_3       0            S.DT  0.1000
# 196        0.068631            SVM   view_3       0            S.DT  0.1000
# 197        0.068631            SVM   view_3       0            S.DT  0.1000
# 198        0.068631            SVM   view_3       0            S.DT  0.1000
# 199        0.068631            SVM   view_3       0            S.DT  0.1000
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample ensemble_method   LMR  \
# 0               0.0       AdaBoost   view_0       0            S.RF  0.55
# 1               0.0       AdaBoost   view_0       0            S.RF  0.55
# 2               0.0       AdaBoost   view_0       0            S.RF  0.55
# 3               0.0       AdaBoost   view_0       0            S.RF  0.55
# 4               0.0       AdaBoost   view_0       0            S.RF  0.55
# ..              ...            ...      ...     ...             ...   ...
# 195             0.0            SVM   view_3       0            S.RF  0.55
# 196             0.0            SVM   view_3       0            S.RF  0.55
# 197             0.0            SVM   view_3       0            S.RF  0.55
# 198             0.0            SVM   view_3       0            S.RF  0.55
# 199             0.0            SVM   view_3       0            S.RF  0.55
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample     ensemble_method  \
# 0               0.0       AdaBoost   view_0       0  S.GradientBoosting
# 1               0.0       AdaBoost   view_0       0  S.GradientBoosting
# 2               0.0       AdaBoost   view_0       0  S.GradientBoosting
# 3               0.0       AdaBoost   view_0       0  S.GradientBoosting
# 4               0.0       AdaBoost   view_0       0  S.GradientBoosting
# ..              ...            ...      ...     ...                 ...
# 195             0.0            SVM   view_3       0  S.GradientBoosting
# 196             0.0            SVM   view_3       0  S.GradientBoosting
# 197             0.0            SVM   view_3       0  S.GradientBoosting
# 198             0.0            SVM   view_3       0  S.GradientBoosting
# 199             0.0            SVM   view_3       0  S.GradientBoosting
#
#        LMR  local_feat_PI local_feat_name  LFR
# 0    0.525       0.050678        view_0_0  1.0
# 1    0.525       0.067704        view_0_1  0.6
# 2    0.525       0.057273        view_0_2  0.8
# 3    0.525       0.076437        view_0_3  0.4
# 4    0.525       0.094740        view_0_4  0.2
# ..     ...            ...             ...  ...
# 195  0.525      -0.003231        view_3_0  1.0
# 196  0.525      -0.000466        view_3_1  0.8
# 197  0.525       0.031079        view_3_2  0.2
# 198  0.525       0.002678        view_3_3  0.4
# 199  0.525      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample ensemble_method     LMR  \
# 0         -0.000037       AdaBoost   view_0       0           S.KNN  0.5625
# 1         -0.000037       AdaBoost   view_0       0           S.KNN  0.5625
# 2         -0.000037       AdaBoost   view_0       0           S.KNN  0.5625
# 3         -0.000037       AdaBoost   view_0       0           S.KNN  0.5625
# 4         -0.000037       AdaBoost   view_0       0           S.KNN  0.5625
# ..              ...            ...      ...     ...             ...     ...
# 195       -0.000037            SVM   view_3       0           S.KNN  0.5625
# 196       -0.000037            SVM   view_3       0           S.KNN  0.5625
# 197       -0.000037            SVM   view_3       0           S.KNN  0.5625
# 198       -0.000037            SVM   view_3       0           S.KNN  0.5625
# 199       -0.000037            SVM   view_3       0           S.KNN  0.5625
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample ensemble_method     LMR  \
# 0               0.0       AdaBoost   view_0       0            S.LR  0.6125
# 1               0.0       AdaBoost   view_0       0            S.LR  0.6125
# 2               0.0       AdaBoost   view_0       0            S.LR  0.6125
# 3               0.0       AdaBoost   view_0       0            S.LR  0.6125
# 4               0.0       AdaBoost   view_0       0            S.LR  0.6125
# ..              ...            ...      ...     ...             ...     ...
# 195             0.0            SVM   view_3       0            S.LR  0.6125
# 196             0.0            SVM   view_3       0            S.LR  0.6125
# 197             0.0            SVM   view_3       0            S.LR  0.6125
# 198             0.0            SVM   view_3       0            S.LR  0.6125
# 199             0.0            SVM   view_3       0            S.LR  0.6125
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample ensemble_method    LMR  \
# 0          0.000754       AdaBoost   view_0       0            S.NB  0.075
# 1          0.000754       AdaBoost   view_0       0            S.NB  0.075
# 2          0.000754       AdaBoost   view_0       0            S.NB  0.075
# 3          0.000754       AdaBoost   view_0       0            S.NB  0.075
# 4          0.000754       AdaBoost   view_0       0            S.NB  0.075
# ..              ...            ...      ...     ...             ...    ...
# 195       -0.000165            SVM   view_3       0            S.NB  0.600
# 196       -0.000165            SVM   view_3       0            S.NB  0.600
# 197       -0.000165            SVM   view_3       0            S.NB  0.600
# 198       -0.000165            SVM   view_3       0            S.NB  0.600
# 199       -0.000165            SVM   view_3       0            S.NB  0.600
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample ensemble_method    LMR  \
# 0          0.000000       AdaBoost   view_0       0           S.MLP  0.875
# 1          0.000000       AdaBoost   view_0       0           S.MLP  0.875
# 2          0.000000       AdaBoost   view_0       0           S.MLP  0.875
# 3          0.000000       AdaBoost   view_0       0           S.MLP  0.875
# 4          0.000000       AdaBoost   view_0       0           S.MLP  0.875
# ..              ...            ...      ...     ...             ...    ...
# 195        0.000258            SVM   view_3       0           S.MLP  0.300
# 196        0.000258            SVM   view_3       0           S.MLP  0.300
# 197        0.000258            SVM   view_3       0           S.MLP  0.300
# 198        0.000258            SVM   view_3       0           S.MLP  0.300
# 199        0.000258            SVM   view_3       0           S.MLP  0.300
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]
#      local_model_PI base predictor modality  sample ensemble_method    LMR  \
# 0         -0.000022       AdaBoost   view_0       0           S.SVM  0.525
# 1         -0.000022       AdaBoost   view_0       0           S.SVM  0.525
# 2         -0.000022       AdaBoost   view_0       0           S.SVM  0.525
# 3         -0.000022       AdaBoost   view_0       0           S.SVM  0.525
# 4         -0.000022       AdaBoost   view_0       0           S.SVM  0.525
# ..              ...            ...      ...     ...             ...    ...
# 195       -0.000044            SVM   view_3       0           S.SVM  0.550
# 196       -0.000044            SVM   view_3       0           S.SVM  0.550
# 197       -0.000044            SVM   view_3       0           S.SVM  0.550
# 198       -0.000044            SVM   view_3       0           S.SVM  0.550
# 199       -0.000044            SVM   view_3       0           S.SVM  0.550
#
#      local_feat_PI local_feat_name  LFR
# 0         0.050678        view_0_0  1.0
# 1         0.067704        view_0_1  0.6
# 2         0.057273        view_0_2  0.8
# 3         0.076437        view_0_3  0.4
# 4         0.094740        view_0_4  0.2
# ..             ...             ...  ...
# 195      -0.003231        view_3_0  1.0
# 196      -0.000466        view_3_1  0.8
# 197       0.031079        view_3_2  0.2
# 198       0.002678        view_3_3  0.4
# 199      -0.000063        view_3_4  0.6
#
# [200 rows x 9 columns]

# %%
EI_int.ensemble_feature_ranking['S.AdaBoost']
# Out:
#    modality   feature     RPS  feature rank ensemble method
# 11   view_2  view_2_1  0.0895           1.0      S.AdaBoost
# 1    view_0  view_0_1  0.2105           2.0      S.AdaBoost
# 19   view_3  view_3_4  0.2200           3.0      S.AdaBoost
# 2    view_0  view_0_2  0.2230           4.0      S.AdaBoost
# 9    view_1  view_1_4  0.2310           5.0      S.AdaBoost
# 12   view_2  view_2_2  0.2560           6.0      S.AdaBoost
# 13   view_2  view_2_3  0.2685           7.0      S.AdaBoost
# 6    view_1  view_1_1  0.3080           8.0      S.AdaBoost
# 3    view_0  view_0_3  0.3155           9.0      S.AdaBoost
# 17   view_3  view_3_2  0.3190          10.0      S.AdaBoost
# 4    view_0  view_0_4  0.3250          11.0      S.AdaBoost
# 8    view_1  view_1_3  0.3300          12.0      S.AdaBoost
# 10   view_2  view_2_0  0.3370          13.0      S.AdaBoost
# 15   view_3  view_3_0  0.3410          14.0      S.AdaBoost
# 7    view_1  view_1_2  0.3520          15.0      S.AdaBoost
# 16   view_3  view_3_1  0.3850          16.0      S.AdaBoost
# 18   view_3  view_3_3  0.3850          17.0      S.AdaBoost
# 14   view_2  view_2_4  0.3915          18.0      S.AdaBoost
# 5    view_1  view_1_0  0.4290          19.0      S.AdaBoost
# 0    view_0  view_0_0  0.4335          20.0      S.AdaBoost
